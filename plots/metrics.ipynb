# %%
from resspect.plot_results import Canvas

# %%
# define parameters
path_to_files = ['/media/RESSPECT/data/PLAsTiCC/for_pipeline/DDF/learn_loop_results/metrics/metrics_RandomSampling_20_batch1.csv',
                '/media/RESSPECT/data/PLAsTiCC/for_pipeline/DDF/learn_loop_results/metrics/metrics_UncSampling_20_batch1.csv']
strategies_list = ['RandomSampling', 'UncSampling']
output_plot = 'metrics_20_batch1.png'

#Initiate the Canvas object, read and plot the results for
# each metric and strategy.
cv = Canvas()
cv.load_metrics(path_to_files=path_to_files,
                    strategies_list=strategies_list)
cv.set_plot_dimensions()
cv.plot_metrics(output_plot_file=output_plot,
                   strategies_list=strategies_list)
